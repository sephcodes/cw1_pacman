# %%
import classifierAgents
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import numpy as np

file = '/Users/youssefawad/Documents/Kings/term_2/6CCS3ML1_Machine_Learning/coursework/cw1_pacman/good-moves.txt'

data, target = classifierAgents.loadData(file)

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

from classifier import Classifier

clf = Classifier()
clf.fit(X_train, y_train)

clf.predict(X_train)
# Out:
# Iteration 1, loss = 1.47694760
# Iteration 2, loss = 1.26508198
# Iteration 3, loss = 1.07281477
# Iteration 4, loss = 0.92194712
# Iteration 5, loss = 0.79237535
# Iteration 6, loss = 0.65444602
# Iteration 7, loss = 0.55332288
# Iteration 8, loss = 0.47616580
# Iteration 9, loss = 0.42038209
# Iteration 10, loss = 0.38271090
# Iteration 11, loss = 0.35750965
# Iteration 12, loss = 0.33917257
# Iteration 13, loss = 0.32734125
# Iteration 14, loss = 0.31995852
# Iteration 15, loss = 0.30694887
# Iteration 16, loss = 0.30028482
# Iteration 17, loss = 0.29566943
# Iteration 18, loss = 0.29266164
# Iteration 19, loss = 0.29432182
# Iteration 20, loss = 0.28413084
# Iteration 21, loss = 0.28235105
# Iteration 22, loss = 0.28339702
# Iteration 23, loss = 0.27759977
# Iteration 24, loss = 0.27841217
# Iteration 25, loss = 0.27455245
# Iteration 26, loss = 0.26897027
# Iteration 27, loss = 0.27024861
# Iteration 28, loss = 0.26630657
# Iteration 29, loss = 0.26666300
# ...

# %%
preds = clf.predict(X_test)
accuracy = np.mean(preds == y_test)
print(f"Test Accuracy: {accuracy}")
# Out:
# [{'ensemble_proba': array([0.36820414, 0.09507972, 0.44802423, 0.0886919 ]), 'ensemble_prediction': np.int64(2), 'individual_probas': {'lr': array([0.28606535, 0.21860462, 0.2746715 , 0.22065853]), 'nn': array([3.73540490e-01, 2.26691715e-03, 6.23753663e-01, 4.38929555e-04]), 'svc': array([0.4450066 , 0.06436762, 0.44564753, 0.04497825])}}, {'ensemble_proba': array([0.07587196, 0.62528324, 0.07104531, 0.22779949]), 'ensemble_prediction': np.int64(1), 'individual_probas': {'lr': array([0.2070192 , 0.29481007, 0.2004446 , 0.29772612]), 'nn': array([1.51390200e-05, 8.29913799e-01, 2.94295748e-07, 1.70070767e-01]), 'svc': array([0.02058155, 0.75112585, 0.01269103, 0.21560158])}}, {'ensemble_proba': array([0.10628968, 0.14425458, 0.67035376, 0.07910198]), 'ensemble_prediction': np.int64(2), 'individual_probas': {'lr': array([0.24816958, 0.2449513 , 0.28939906, 0.21748006]), 'nn': array([1.92109965e-02, 1.31691691e-02, 9.66878465e-01, 7.41369694e-04]), 'svc': array([0.05148847, 0.17464328,
# ...

# %%
clf.predict(X_test[0])
# Out:
# [{'ensemble_proba': array([0.36820414, 0.09507972, 0.44802423, 0.0886919 ]), 'ensemble_prediction': np.int64(2), 'individual_probas': {'lr': array([0.28606535, 0.21860462, 0.2746715 , 0.22065853]), 'nn': array([3.73540490e-01, 2.26691715e-03, 6.23753663e-01, 4.38929555e-04]), 'svc': array([0.4450066 , 0.06436762, 0.44564753, 0.04497825])}}]
# array([2])

# %%
y_test[0]
# Out:
# 0

# %%
clf = Classifier()
clf.fit(X_train, y_train)
clf.predict(X_train)
# Out:
# Iteration 1, loss = 1.48516383
# Iteration 2, loss = 1.24235809
# Iteration 3, loss = 1.09953973
# Iteration 4, loss = 0.96758459
# Iteration 5, loss = 0.85012819
# Iteration 6, loss = 0.75186611
# Iteration 7, loss = 0.66512333
# Iteration 8, loss = 0.59265367
# Iteration 9, loss = 0.52797574
# Iteration 10, loss = 0.47605387
# Iteration 11, loss = 0.43524767
# Iteration 12, loss = 0.40394623
# Iteration 13, loss = 0.37737484
# Iteration 14, loss = 0.36039185
# Iteration 15, loss = 0.34642583
# Iteration 16, loss = 0.33597191
# Iteration 17, loss = 0.32527531
# Iteration 18, loss = 0.31787891
# Iteration 19, loss = 0.31199559
# Iteration 20, loss = 0.30542784
# Iteration 21, loss = 0.30376575
# Iteration 22, loss = 0.29708813
# Iteration 23, loss = 0.29185940
# Iteration 24, loss = 0.29161289
# Iteration 25, loss = 0.28872676
# Iteration 26, loss = 0.28399684
# Iteration 27, loss = 0.27952985
# Iteration 28, loss = 0.27939036
# Iteration 29, loss = 0.27828482
# ...

# %%
preds = clf.predict(X_test)
accuracy = np.mean(np.array(preds) == y_test)
print(f"Test Accuracy: {accuracy}")
# Out:
# [{'ensemble_proba': array([0.43367868, 0.09199427, 0.38619245, 0.0881346 ]), 'ensemble_prediction': np.int64(0), 'individual_probas': {'lr': array([0.28606535, 0.21860462, 0.2746715 , 0.22065853]), 'nn': array([5.38286144e-01, 4.04925178e-05, 4.61646701e-01, 2.66621109e-05]), 'svc': array([0.47668455, 0.0573377 , 0.42225913, 0.04371861])}}, {'ensemble_proba': array([0.07564423, 0.63032938, 0.07053347, 0.22349293]), 'ensemble_prediction': np.int64(1), 'individual_probas': {'lr': array([0.2070192 , 0.29481007, 0.2004446 , 0.29772612]), 'nn': array([8.70755890e-05, 8.17061163e-01, 2.24975443e-07, 1.82851537e-01]), 'svc': array([0.01982641, 0.77911689, 0.01115558, 0.18990111])}}, {'ensemble_proba': array([0.10347883, 0.13386976, 0.68433204, 0.07831937]), 'ensemble_prediction': np.int64(2), 'individual_probas': {'lr': array([0.24816958, 0.2449513 , 0.28939906, 0.21748006]), 'nn': array([1.17026422e-02, 3.04014071e-03, 9.85239128e-01, 1.80893177e-05]), 'svc': array([0.05056425, 0.15361785,
# ...

# %%
# [{'ensemble_proba': array([0.0740768, 0.6420859, 0.0703392, 0.2134981]), 'ensemble_prediction': np.int64(1), 'individual_probas': {'lr': array([0.2070192 , 0.29481007, 0.2004446 , 0.29772612]), 'nn': array([2.61239700e-04, 8.47599125e-01, 9.10480552e-05, 1.52048587e-01]), 'svc': array([0.01494995, 0.7838485 , 0.01048195, 0.1907196 ])}}]
# Test Accuracy: 0.6153846153846154

# %%
clf.predict(X_test[0])
# Out:
# [{'ensemble_proba': array([0.43367868, 0.09199427, 0.38619245, 0.0881346 ]), 'ensemble_prediction': np.int64(0), 'individual_probas': {'lr': array([0.28606535, 0.21860462, 0.2746715 , 0.22065853]), 'nn': array([5.38286144e-01, 4.04925178e-05, 4.61646701e-01, 2.66621109e-05]), 'svc': array([0.47668455, 0.0573377 , 0.42225913, 0.04371861])}}]
# array([0])

# %%
# [{'ensemble_proba': array([0.40894429, 0.09250997, 0.40947176, 0.08907398]), 'ensemble_prediction': np.int64(2), 'individual_probas': {'lr': array([0.28606535, 0.21860462, 0.2746715 , 0.22065853]), 'nn': array([4.81571378e-01, 7.25004665e-04, 5.17679304e-01, 2.43139137e-05]), 'svc': array([0.45919614, 0.05820029, 0.43606449, 0.04653909])}}]
